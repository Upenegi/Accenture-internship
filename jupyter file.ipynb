# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1= pd.read_csv(r'E:\Python_2023\Accenture Internship\Content.csv')
df1.head(2)
# Out:
#    Unnamed: 0                            Content ID
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2  \
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
#
#                                 User ID   Type        Category
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying  \
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...

# %%
df2= pd.read_csv(r'E:\Python_2023\Accenture Internship\Reactions.csv')
df2.head(2)
# Out:
#    Unnamed: 0                            Content ID
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2  \
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50

# %%
df3= pd.read_csv(r'E:\Python_2023\Accenture Internship\ReactionTypes.csv')
df3.head(2)
# Out:
#    Unnamed: 0   Type Sentiment  Score
# 0           0  heart  positive     60
# 1           1   want  positive     70

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#      Unnamed: 0                            Content ID
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2  \
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 994         994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type        Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying  \
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# ...

# %%
df1.drop(columns =['User ID', 'URL'], inplace=True)

# %%
df1.rename(columns = {'Type': 'Content_Type'},inplace=True)

# %%
df1
# Out:
#      Unnamed: 0                            Content ID Content_Type
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  \
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6        photo
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180        video
# ..          ...                                   ...          ...
# 994         994  c54b49c4-b1f2-4641-8595-1cbd19937845        photo
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c          GIF
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b        audio
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56        audio
#
#            Category
# 0          Studying
# 1    healthy eating
# 2    healthy eating
# 3        technology
# 4              food
# ..              ...
# ...

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
df2.dropna(inplace=True)

# %%
df2
# Out:
#        Unnamed: 0                            Content ID
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2  \
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# ...

# %%
df2.drop(columns =['User ID'], inplace=True)

# %%
df2.rename(columns = {'Type': 'Reaction_Type'},inplace=True)

# %%
df2
# Out:
#        Unnamed: 0                            Content ID Reaction_Type
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  \
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...           ...                                   ...           ...
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime
# 1      2020-11-07 09:43:50
# 2      2021-06-17 12:22:51
# 3      2021-04-18 05:13:58
# ...

# %%
df1.to_csv(r'E:\Python_2023\Accenture Internship\clean data\content_clean.csv', index='FALSE')

# %%
df2.to_csv(r'E:\Python_2023\Accenture Internship\clean data\Reactions_clean.csv', index='FALSE')

# %%
df4=df2.merge(df1, on = 'Content ID', how='left').merge(df3, left_on ='Reaction_Type', right_on = 'Type', how='left')[['Content ID', 'Reaction_Type', 'Datetime', 'Content_Type', 'Category', 'Type', 'Sentiment', 'Score']]

# %%
df4.head(2)
# Out:
#                              Content ID Reaction_Type             Datetime
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50  \
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
#
#   Content_Type  Category     Type Sentiment  Score
# 0        photo  Studying  disgust  negative      0
# 1        photo  Studying  dislike  negative     10

# %%
grouped =df4.groupby('Category').sum('Score')

# %%
sorted_grouped = grouped.sort_values(['Score'],ascending=False)

# %%
sorted_grouped.head()
# Out:
#                 Score
# Category
# travel          53935
# science         53657
# healthy eating  52745
# animals         52443
# cooking         49681

# %%
df4.to_csv(r'E:\Python_2023\Accenture Internship\combined_data.csv', index='FALSE')
